# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !pip install -q keras

# %%
import keras

# %%
# !pip install split-folders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl.metadata (6.2 kB)
# Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import splitfolders
splitfolders.ratio(
    "/content/drive/MyDrive/DR/archive (1)/Dataset",
   output="./dataset",
   seed=7,
   ratio=(0.8,0.1, 0.1)
)
# Out:
# Copying files: 3562 files [01:01, 58.28 files/s]

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Define the CNN model
model = models.Sequential()

# Convolutional layers
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

# Flatten layer
model.add(layers.Flatten())

# Change this line to match the number of classes in your dataset
num_classes = 5  # Modify based on your dataset

# Dense (fully connected) layers
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))  # Optional dropout for regularization
model.add(layers.Dense(num_classes, activation='sigmoid'))  # Assuming binary classification
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 86528)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    11,075,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,169,605 (42.61 MB)
#  Trainable params: 11,169,605 (42.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Data augmentation for training
train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Specify the paths to your train, test, and validation datasets
train_path = '/content/dataset/train'
test_path = '/content/dataset/test'
val_path = '/content/dataset/val'

# %%
# Set batch size
batch_size = 32

# Create generators for training, validation, and testing
train_generator = train_datagen.flow_from_directory(train_path,
                                                    target_size=(224, 224),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')


validation_generator = test_datagen.flow_from_directory(val_path,
                                                        target_size=(224, 224),
                                                        batch_size=batch_size,
                                                        class_mode='categorical')

test_generator = test_datagen.flow_from_directory(test_path,
                                                  target_size=(224, 224),
                                                  batch_size=batch_size,
                                                  class_mode='categorical')
# Out:
# Found 2848 images belonging to 5 classes.
# Found 353 images belonging to 5 classes.
# Found 361 images belonging to 5 classes.

# %%
# Train the model
history = model.fit(train_generator,
                    steps_per_epoch=train_generator.samples // batch_size,
                    epochs=100,  # Adjust the number of epochs as needed
                    validation_data=validation_generator,
                    validation_steps=validation_generator.samples // batch_size)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 47s 430ms/step - accuracy: 0.4451 - loss: 0.4419 - val_accuracy: 0.9176 - val_loss: 0.1624
# Epoch 2/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 413ms/step - accuracy: 0.8031 - loss: 0.2230 - val_accuracy: 0.9545 - val_loss: 0.0835
# Epoch 3/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 41s 417ms/step - accuracy: 0.8745 - loss: 0.1614 - val_accuracy: 0.9631 - val_loss: 0.0629
# Epoch 4/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 36s 409ms/step - accuracy: 0.9109 - loss: 0.1348 - val_accuracy: 0.9688 - val_loss: 0.0505
# Epoch 5/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 407ms/step - accuracy: 0.9124 - loss: 0.1220 - val_accuracy: 0.9631 - val_loss: 0.0489
# Epoch 6/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 418ms/step - accuracy: 0.9341 - loss: 0.1021 - val_accuracy: 0.9688 - val_loss: 0.0354
# Epoch 7/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 416ms/step - accuracy: 0.9450 - loss: 0.0907 - val_accuracy: 0.9830 - val_loss: 0.0330
# Epoch 8/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 414ms/step - accuracy: 0.9520 - loss: 0.0789 - val_accuracy: 0.9830 - val_loss: 0.0356
# Epoch 9/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 36s 402ms/step - accuracy: 0.9546 - loss: 0.0747 - val_accuracy: 0.9858 - val_loss: 0.0297
# Epoch 10/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 420ms/step - accuracy: 0.9581 - loss: 0.0644 - val_accuracy: 0.9631 - val_loss: 0.0408
# Epoch 11/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 420ms/step - accuracy: 0.9606 - loss: 0.0667 - val_accuracy: 0.9858 - val_loss: 0.0245
# Epoch 12/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 38s 424ms/step - accuracy: 0.9665 - loss: 0.0673 - val_accuracy: 0.9801 - val_loss: 0.0267
# Epoch 13/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 415ms/step - accuracy: 0.9618 - loss: 0.0590 - val_accuracy: 0.9801 - val_loss: 0.0293
# Epoch 14/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 36s 405ms/step - accuracy: 0.9614 - loss: 0.0636 - val_accuracy: 0.9886 - val_loss: 0.0225
# Epoch 15/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 416ms/step - accuracy: 0.9751 - loss: 0.0464 - val_accuracy: 0.9858 - val_loss: 0.0233
# Epoch 16/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 414ms/step - accuracy: 0.9703 - loss: 0.0546 - val_accuracy: 0.9915 - val_loss: 0.0196
# Epoch 17/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 418ms/step - accuracy: 0.9688 - loss: 0.0488 - val_accuracy: 0.9858 - val_loss: 0.0262
# Epoch 18/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 36s 404ms/step - accuracy: 0.9674 - loss: 0.0508 - val_accuracy: 0.9858 - val_loss: 0.0209
# Epoch 19/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 412ms/step - accuracy: 0.9750 - loss: 0.0414 - val_accuracy: 0.9858 - val_loss: 0.0291
# Epoch 20/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 415ms/step - accuracy: 0.9714 - loss: 0.0492 - val_accuracy: 0.9830 - val_loss: 0.0255
# Epoch 21/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 417ms/step - accuracy: 0.9721 - loss: 0.0462 - val_accuracy: 0.9915 - val_loss: 0.0201
# Epoch 22/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 36s 410ms/step - accuracy: 0.9708 - loss: 0.0453 - val_accuracy: 0.9915 - val_loss: 0.0188
# Epoch 23/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 36s 401ms/step - accuracy: 0.9744 - loss: 0.0454 - val_accuracy: 0.9858 - val_loss: 0.0272
# Epoch 24/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 413ms/step - accuracy: 0.9718 - loss: 0.0379 - val_accuracy: 0.9801 - val_loss: 0.0288
# Epoch 25/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 417ms/step - accuracy: 0.9736 - loss: 0.0435 - val_accuracy: 0.9943 - val_loss: 0.0171
# Epoch 26/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 412ms/step - accuracy: 0.9766 - loss: 0.0363 - val_accuracy: 0.9830 - val_loss: 0.0230
# Epoch 27/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 36s 405ms/step - accuracy: 0.9674 - loss: 0.0445 - val_accuracy: 0.9858 - val_loss: 0.0197
# Epoch 28/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 413ms/step - accuracy: 0.9772 - loss: 0.0399 - val_accuracy: 0.9830 - val_loss: 0.0241
# Epoch 29/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 417ms/step - accuracy: 0.9758 - loss: 0.0415 - val_accuracy: 0.9858 - val_loss: 0.0206
# Epoch 30/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 413ms/step - accuracy: 0.9772 - loss: 0.0378 - val_accuracy: 0.9858 - val_loss: 0.0231
# Epoch 31/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 41s 419ms/step - accuracy: 0.9808 - loss: 0.0351 - val_accuracy: 0.9915 - val_loss: 0.0193
# Epoch 32/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 414ms/step - accuracy: 0.9820 - loss: 0.0293 - val_accuracy: 0.9858 - val_loss: 0.0197
# Epoch 33/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 36s 407ms/step - accuracy: 0.9767 - loss: 0.0423 - val_accuracy: 0.9915 - val_loss: 0.0198
# Epoch 34/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 36s 406ms/step - accuracy: 0.9826 - loss: 0.0356 - val_accuracy: 0.9943 - val_loss: 0.0159
# Epoch 35/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 417ms/step - accuracy: 0.9773 - loss: 0.0361 - val_accuracy: 0.9915 - val_loss: 0.0181
# Epoch 36/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 413ms/step - accuracy: 0.9806 - loss: 0.0350 - val_accuracy: 0.9886 - val_loss: 0.0171
# Epoch 37/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 415ms/step - accuracy: 0.9759 - loss: 0.0360 - val_accuracy: 0.9744 - val_loss: 0.0349
# Epoch 38/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 36s 400ms/step - accuracy: 0.9806 - loss: 0.0328 - val_accuracy: 0.9915 - val_loss: 0.0182
# Epoch 39/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 415ms/step - accuracy: 0.9817 - loss: 0.0280 - val_accuracy: 0.9801 - val_loss: 0.0233
# Epoch 40/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 414ms/step - accuracy: 0.9816 - loss: 0.0263 - val_accuracy: 0.9943 - val_loss: 0.0193
# Epoch 41/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 417ms/step - accuracy: 0.9830 - loss: 0.0285 - val_accuracy: 0.9915 - val_loss: 0.0215
# Epoch 42/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 36s 403ms/step - accuracy: 0.9828 - loss: 0.0309 - val_accuracy: 0.9858 - val_loss: 0.0269
# Epoch 43/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 409ms/step - accuracy: 0.9769 - loss: 0.0376 - val_accuracy: 0.9886 - val_loss: 0.0220
# Epoch 44/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 413ms/step - accuracy: 0.9835 - loss: 0.0291 - val_accuracy: 0.9830 - val_loss: 0.0245
# Epoch 45/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 421ms/step - accuracy: 0.9847 - loss: 0.0283 - val_accuracy: 0.9943 - val_loss: 0.0165
# Epoch 46/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 40s 413ms/step - accuracy: 0.9790 - loss: 0.0301 - val_accuracy: 0.9915 - val_loss: 0.0202
# Epoch 47/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 421ms/step - accuracy: 0.9853 - loss: 0.0238 - val_accuracy: 0.9858 - val_loss: 0.0264
# Epoch 48/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 36s 404ms/step - accuracy: 0.9786 - loss: 0.0320 - val_accuracy: 0.9915 - val_loss: 0.0211
# Epoch 49/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 412ms/step - accuracy: 0.9815 - loss: 0.0267 - val_accuracy: 0.9858 - val_loss: 0.0219
# Epoch 50/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 414ms/step - accuracy: 0.9797 - loss: 0.0286 - val_accuracy: 0.9943 - val_loss: 0.0194
# Epoch 51/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 38s 422ms/step - accuracy: 0.9821 - loss: 0.0336 - val_accuracy: 0.9915 - val_loss: 0.0201
# Epoch 52/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 421ms/step - accuracy: 0.9821 - loss: 0.0273 - val_accuracy: 0.9886 - val_loss: 0.0188
# Epoch 53/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 410ms/step - accuracy: 0.9787 - loss: 0.0279 - val_accuracy: 0.9943 - val_loss: 0.0214
# Epoch 54/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 41s 413ms/step - accuracy: 0.9868 - loss: 0.0250 - val_accuracy: 0.9830 - val_loss: 0.0266
# Epoch 55/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 36s 408ms/step - accuracy: 0.9877 - loss: 0.0222 - val_accuracy: 0.9858 - val_loss: 0.0224
# Epoch 56/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 413ms/step - accuracy: 0.9825 - loss: 0.0247 - val_accuracy: 0.9886 - val_loss: 0.0218
# Epoch 57/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 421ms/step - accuracy: 0.9863 - loss: 0.0230 - val_accuracy: 0.9915 - val_loss: 0.0231
# Epoch 58/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 418ms/step - accuracy: 0.9808 - loss: 0.0230 - val_accuracy: 0.9943 - val_loss: 0.0239
# Epoch 59/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 421ms/step - accuracy: 0.9877 - loss: 0.0243 - val_accuracy: 0.9886 - val_loss: 0.0236
# Epoch 60/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 36s 405ms/step - accuracy: 0.9858 - loss: 0.0225 - val_accuracy: 0.9886 - val_loss: 0.0223
# Epoch 61/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 38s 420ms/step - accuracy: 0.9830 - loss: 0.0230 - val_accuracy: 0.9915 - val_loss: 0.0173
# Epoch 62/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 418ms/step - accuracy: 0.9852 - loss: 0.0263 - val_accuracy: 0.9801 - val_loss: 0.0306
# Epoch 63/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 38s 424ms/step - accuracy: 0.9823 - loss: 0.0222 - val_accuracy: 0.9858 - val_loss: 0.0265
# Epoch 64/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 417ms/step - accuracy: 0.9834 - loss: 0.0245 - val_accuracy: 0.9801 - val_loss: 0.0256
# Epoch 65/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 36s 410ms/step - accuracy: 0.9814 - loss: 0.0258 - val_accuracy: 0.9886 - val_loss: 0.0222
# Epoch 66/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 409ms/step - accuracy: 0.9864 - loss: 0.0209 - val_accuracy: 0.9886 - val_loss: 0.0240
# Epoch 67/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 38s 421ms/step - accuracy: 0.9898 - loss: 0.0222 - val_accuracy: 0.9801 - val_loss: 0.0267
# Epoch 68/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 417ms/step - accuracy: 0.9849 - loss: 0.0206 - val_accuracy: 0.9943 - val_loss: 0.0213
# Epoch 69/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 38s 424ms/step - accuracy: 0.9853 - loss: 0.0226 - val_accuracy: 0.9886 - val_loss: 0.0255
# Epoch 70/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 36s 410ms/step - accuracy: 0.9785 - loss: 0.0255 - val_accuracy: 0.9915 - val_loss: 0.0217
# Epoch 71/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 417ms/step - accuracy: 0.9873 - loss: 0.0189 - val_accuracy: 0.9886 - val_loss: 0.0229
# Epoch 72/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 417ms/step - accuracy: 0.9804 - loss: 0.0307 - val_accuracy: 0.9858 - val_loss: 0.0243
# Epoch 73/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 38s 424ms/step - accuracy: 0.9847 - loss: 0.0251 - val_accuracy: 0.9915 - val_loss: 0.0167
# Epoch 74/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 418ms/step - accuracy: 0.9872 - loss: 0.0180 - val_accuracy: 0.9886 - val_loss: 0.0204
# Epoch 75/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 42s 424ms/step - accuracy: 0.9900 - loss: 0.0171 - val_accuracy: 0.9830 - val_loss: 0.0233
# Epoch 76/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 416ms/step - accuracy: 0.9847 - loss: 0.0202 - val_accuracy: 0.9858 - val_loss: 0.0235
# Epoch 77/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 36s 408ms/step - accuracy: 0.9867 - loss: 0.0183 - val_accuracy: 0.9886 - val_loss: 0.0199
# Epoch 78/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 410ms/step - accuracy: 0.9863 - loss: 0.0197 - val_accuracy: 0.9886 - val_loss: 0.0259
# Epoch 79/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 38s 425ms/step - accuracy: 0.9877 - loss: 0.0177 - val_accuracy: 0.9858 - val_loss: 0.0224
# Epoch 80/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 415ms/step - accuracy: 0.9885 - loss: 0.0159 - val_accuracy: 0.9915 - val_loss: 0.0206
# Epoch 81/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 421ms/step - accuracy: 0.9877 - loss: 0.0160 - val_accuracy: 0.9943 - val_loss: 0.0162
# Epoch 82/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 36s 401ms/step - accuracy: 0.9875 - loss: 0.0192 - val_accuracy: 0.9943 - val_loss: 0.0195
# Epoch 83/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 418ms/step - accuracy: 0.9790 - loss: 0.0223 - val_accuracy: 0.9830 - val_loss: 0.0223
# Epoch 84/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 412ms/step - accuracy: 0.9896 - loss: 0.0153 - val_accuracy: 0.9886 - val_loss: 0.0212
# Epoch 85/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 420ms/step - accuracy: 0.9917 - loss: 0.0136 - val_accuracy: 0.9886 - val_loss: 0.0234
# Epoch 86/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 414ms/step - accuracy: 0.9890 - loss: 0.0203 - val_accuracy: 0.9886 - val_loss: 0.0194
# Epoch 87/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 412ms/step - accuracy: 0.9837 - loss: 0.0191 - val_accuracy: 0.9858 - val_loss: 0.0265
# Epoch 88/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 412ms/step - accuracy: 0.9832 - loss: 0.0187 - val_accuracy: 0.9886 - val_loss: 0.0212
# Epoch 89/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 38s 422ms/step - accuracy: 0.9829 - loss: 0.0201 - val_accuracy: 0.9744 - val_loss: 0.0354
# Epoch 90/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 416ms/step - accuracy: 0.9846 - loss: 0.0183 - val_accuracy: 0.9886 - val_loss: 0.0230
# Epoch 91/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 38s 424ms/step - accuracy: 0.9853 - loss: 0.0190 - val_accuracy: 0.9915 - val_loss: 0.0218
# Epoch 92/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 40s 414ms/step - accuracy: 0.9867 - loss: 0.0169 - val_accuracy: 0.9915 - val_loss: 0.0183
# Epoch 93/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 420ms/step - accuracy: 0.9886 - loss: 0.0148 - val_accuracy: 0.9915 - val_loss: 0.0186
# Epoch 94/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 36s 403ms/step - accuracy: 0.9888 - loss: 0.0200 - val_accuracy: 0.9886 - val_loss: 0.0225
# Epoch 95/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 38s 426ms/step - accuracy: 0.9866 - loss: 0.0180 - val_accuracy: 0.9886 - val_loss: 0.0237
# Epoch 96/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 37s 420ms/step - accuracy: 0.9912 - loss: 0.0136 - val_accuracy: 0.9858 - val_loss: 0.0183
# Epoch 97/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 38s 424ms/step - accuracy: 0.9907 - loss: 0.0199 - val_accuracy: 0.9858 - val_loss: 0.0256
# Epoch 98/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 40s 418ms/step - accuracy: 0.9853 - loss: 0.0192 - val_accuracy: 0.9915 - val_loss: 0.0202
# Epoch 99/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 38s 424ms/step - accuracy: 0.9902 - loss: 0.0139 - val_accuracy: 0.9943 - val_loss: 0.0198
# Epoch 100/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 36s 402ms/step - accuracy: 0.9934 - loss: 0.0113 - val_accuracy: 0.9943 - val_loss: 0.0196

# %%
# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_generator, steps=test_generator.samples // batch_size)
print(f'Test accuracy: {test_acc}')

# Save the trained model
model.save('/content/drive/MyDrive/savedmodels/epochsCNN.h5')
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.9875 - loss: 0.0516
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test accuracy: 0.9914772510528564

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define directories and parameters for test data
test_data_dir = '/content/dataset/test'
batch_size = 32
input_shape = (224, 224)  # Ensure it matches the input shape used during training

# Test data generator (only rescale)
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=input_shape,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False  # Important: set shuffle to False for test data
)

# Load the saved model
model = load_model('/content/drive/MyDrive/savedmodels/epochsCNN.h5')  # Replace with your saved model file name

# Evaluate the model on the test set
evaluation = model.evaluate(test_generator, verbose=1)

# Extract metrics
test_loss = evaluation[0]
test_accuracy = evaluation[1]

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy*100:.2f}%")
# Out:
# Found 361 images belonging to 5 classes.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - accuracy: 0.9965 - loss: 0.0192
# Test Loss: 0.0413
# Test Accuracy: 99.17%

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(test_generator, steps=test_generator.samples // batch_size)
print(f'Test accuracy: {test_accuracy * 100:.2f}%')
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.9969 - loss: 0.0175
# Test accuracy: 99.15%

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt


# Assuming you have your test data generator and labels
test_generator.reset()  # Reset the generator before using it for predictions

# Generate predictions
Y_pred = model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)

# Get true labels
true_labels = test_generator.classes

# Generate confusion matrix
confusion_mtx = confusion_matrix(true_labels, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues',
            xticklabels=test_generator.class_indices,
            yticklabels=test_generator.class_indices)
plt.xlabel('True labels')
plt.ylabel('Predicted')
plt.title('Confusion Matrix')
plt.show()

# Classification report
print(classification_report(true_labels, y_pred, target_names=test_generator.class_indices.keys()))
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 172ms/step
#                 precision    recall  f1-score   support
#
#           Mild       1.00      1.00      1.00        54
#       Moderate       1.00      1.00      1.00        40
#          No_DR       0.97      1.00      0.99        99
# Proliferate_DR       1.00      0.97      0.99       110
#         Severe       1.00      1.00      1.00        58
#
#       accuracy                           0.99       361
#      macro avg       0.99      0.99      0.99       361
#   weighted avg       0.99      0.99      0.99       361

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have your test data generator and labels
test_generator.reset()  # Reset the generator before using it for predictions

# Generate predictions
Y_pred = model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)

# Get true labels
true_labels = test_generator.classes

# Generate confusion matrix
confusion_mtx = confusion_matrix(true_labels, y_pred)

# Generate confusion matrix with different colormaps
cmaps = ['viridis', 'cividis', 'plasma', 'magma', 'tab10']
for cmap in cmaps:
    plt.figure(figsize=(8, 6))
    sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap=cmap,
                xticklabels=test_generator.class_indices,
                yticklabels=test_generator.class_indices)
    plt.xlabel('True labels')
    plt.ylabel('Predicted labels')
    plt.title(f'Confusion Matrix (Colormap: {cmap})')
    plt.show()
# Classification report
print(classification_report(true_labels, y_pred, target_names=test_generator.class_indices.keys()))
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step
#                 precision    recall  f1-score   support
#
#           Mild       1.00      1.00      1.00        54
#       Moderate       1.00      1.00      1.00        40
#          No_DR       0.97      1.00      0.99        99
# Proliferate_DR       1.00      0.97      0.99       110
#         Severe       1.00      1.00      1.00        58
#
#       accuracy                           0.99       361
#      macro avg       0.99      0.99      0.99       361
#   weighted avg       0.99      0.99      0.99       361

# %%
import matplotlib.pyplot as plt

# Plot the training and validation loss over epochs
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot the training and validation accuracy over epochs
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define directories and parameters for test data
test_data_dir = '/content/dataset/test'
batch_size = 32
input_shape = (224, 224)  # Ensure it matches the input shape used during training

# Test data generator (only rescale)
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=input_shape,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False  # Important: set shuffle to False for test data
)

# Load the saved model
model = load_model('/content/drive/MyDrive/savedmodels/epochsCNN.h5')  # Replace with your saved model file name

# Evaluate the model on the test set
evaluation = model.evaluate(test_generator, verbose=1)

# Extract metrics
test_loss = evaluation[0]
test_accuracy = evaluation[1]

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy*100:.2f}%")
# Out:
# Found 361 images belonging to 5 classes.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - accuracy: 0.9965 - loss: 0.0192
# Test Loss: 0.0413
# Test Accuracy: 99.17%

# %%
import matplotlib.pyplot as plt

# Get training and validation accuracy
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# Get training and validation loss
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Load the trained model
model = tf.keras.models.load_model('/content/drive/MyDrive/savedmodels/epochsCNN.h5')

# Load and preprocess the input image
image_path = '/content/drive/MyDrive/DR/archive (1)/Dataset/Mild/005b95c28852.png' # Replace with the path to your input image
img = image.load_img(image_path, target_size=(224, 224))
img = image.img_to_array(img)
img = np.expand_dims(img, axis=0)
img = img / 255.0  # Normalize the image

# Classify the input image
predictions = model.predict(img)

# Get the class label
class_label = np.argmax(predictions)
img = mpimg.imread(image_path)
plt.imshow(img)
plt.axis('off')  # Turn off axis labels
plt.show()

# Define your class labels
class_labels = ['Mild', 'Moderate', 'No_DR', 'Proliferate_DR','Severe']  # Replace with your class labels

predicted_class_label = class_labels[class_label]

print(f'Predicted class: {predicted_class_label}')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 834ms/step
# Predicted class: Mild

# %% [markdown]
# # New Section

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Load the trained model
model = tf.keras.models.load_model('/content/drive/MyDrive/savedmodels/epochsCNN.h5')

# Load and preprocess the input image
image_path = '/content/drive/MyDrive/DR/archive (1)/Dataset/Moderate/10220_left.png'  # Replace with the path to your input image
img = image.load_img(image_path, target_size=(224, 224))
img = image.img_to_array(img)
img = np.expand_dims(img, axis=0)
img = img / 255.0  # Normalize the image

# Classify the input image
predictions = model.predict(img)

# Get the class label
class_label = np.argmax(predictions)
img = mpimg.imread(image_path)
plt.imshow(img)
plt.axis('off')  # Turn off axis labels
plt.show()

# Define your class labels
class_labels = ['Mild', 'Moderate', 'No_DR', 'Proliferate_DR','Severe']  # Replace with your class labels

predicted_class_label = class_labels[class_label]

print(f'Predicted class: {predicted_class_label}')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# Predicted class: Moderate

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Load the trained model
model = tf.keras.models.load_model('/content/drive/MyDrive/savedmodels/epochsCNN.h5')

# Load and preprocess the input image
image_path = '/content/drive/MyDrive/DR/archive (1)/Dataset/No_DR/002c21358ce6.png'  # Replace with the path to your input image
img = image.load_img(image_path, target_size=(224, 224))
img = image.img_to_array(img)
img = np.expand_dims(img, axis=0)
img = img / 255.0  # Normalize the image

# Classify the input image
predictions = model.predict(img)

# Get the class label
class_label = np.argmax(predictions)
img = mpimg.imread(image_path)
plt.imshow(img)
plt.axis('off')  # Turn off axis labels
plt.show()

# Define your class labels
class_labels = ['Mild', 'Moderate', 'No_DR', 'Proliferate_DR','Severe']  # Replace with your class labels

predicted_class_label = class_labels[class_label]

print(f'Predicted class: {predicted_class_label}')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# Predicted class: No_DR

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Load the trained model
model = tf.keras.models.load_model('/content/drive/MyDrive/savedmodels/epochsCNN.h5')

# Load and preprocess the input image
image_path = '/content/drive/MyDrive/DR/archive (1)/Dataset/Proliferate_DR/000c1434d8d7.png'  # Replace with the path to your input image
img = image.load_img(image_path, target_size=(224, 224))
img = image.img_to_array(img)
img = np.expand_dims(img, axis=0)
img = img / 255.0  # Normalize the image

# Classify the input image
predictions = model.predict(img)

# Get the class label
class_label = np.argmax(predictions)
img = mpimg.imread(image_path)
plt.imshow(img)
plt.axis('off')  # Turn off axis labels
plt.show()

# Define your class labels
class_labels = ['Mild', 'Moderate', 'No_DR', 'Proliferate_DR','Severe']  # Replace with your class labels

predicted_class_label = class_labels[class_label]

print(f'Predicted class: {predicted_class_label}')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a8dc068f560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# Predicted class: Proliferate_DR

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Load the trained model
model = tf.keras.models.load_model('/content/drive/MyDrive/savedmodels/epochsCNN.h5')

# Load and preprocess the input image
image_path = '/content/drive/MyDrive/DR/archive (1)/Dataset/Severe/0097f532ac9f.png'  # Replace with the path to your input image
img = image.load_img(image_path, target_size=(224, 224))
img = image.img_to_array(img)
img = np.expand_dims(img, axis=0)
img = img / 255.0  # Normalize the image

# Classify the input image
predictions = model.predict(img)

# Get the class label
class_label = np.argmax(predictions)
img = mpimg.imread(image_path)
plt.imshow(img)
plt.axis('off')  # Turn off axis labels
plt.show()

# Define your class labels
class_labels = ['Mild', 'Moderate', 'No_DR', 'Proliferate_DR','Severe']  # Replace with your class labels

predicted_class_label = class_labels[class_label]

print(f'Predicted class: {predicted_class_label}')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:6 out of the last 18 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a8dc055fec0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# Predicted class: Severe

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

# Define the number of classes
num_classes = 4  # Change this to match the number of classes in your dataset

# Initialize variables to store true labels and predicted labels
true_labels = []
predicted_labels = []

# Load the trained model
model = tf.keras.models.load_model('/content/drive/MyDrive/savedmodels/epochsCNN.h5')

# Load and preprocess the test data
test_data_dir = '/content/dataset/test'  # Replace with the path to your test data
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(224, 224),
    batch_size=1,  # Set batch_size to 1 for individual predictions
    class_mode='categorical',
    shuffle=False  # Don't shuffle the data
)

# Make predictions on the test data and record true and predicted labels
for i in range(test_generator.samples):
    x, y = test_generator[i]
    true_label = np.argmax(y)
    predicted_label = np.argmax(model.predict(x))
    true_labels.append(true_label)
    predicted_labels.append(predicted_label)

# Create the confusion matrix
confusion = confusion_matrix(true_labels, predicted_labels)

print("Confusion Matrix:")
print(confusion)

# You can also print a classification report with precision, recall, and F1-score
target_names = ['Mild', 'Moderate', 'No_DR', 'Proliferate_DR','Severe']  # Replace with your class labels
report = classification_report(true_labels, predicted_labels, target_names=target_names)
print("\nClassification Report:")
print(report)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Found 361 images belonging to 5 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Confusion Matrix:
# [[ 54   0   0   0   0]
#  [  0  40   0   0   0]
#  [  0   0  99   0   0]
#  [  0   0   3 107   0]
#  [  0   0   0   0  58]]
#
# Classification Report:
#                 precision    recall  f1-score   support
#
#           Mild       1.00      1.00      1.00        54
#       Moderate       1.00      1.00      1.00        40
#          No_DR       0.97      1.00      0.99        99
# Proliferate_DR       1.00      0.97      0.99       110
#         Severe       1.00      1.00      1.00        58
#
#       accuracy                           0.99       361
#      macro avg       0.99      0.99      0.99       361
#   weighted avg       0.99      0.99      0.99       361

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import load_model

# Load the saved model
model = load_model('/content/drive/MyDrive/savedmodels/epochsCNN.h5')  # Load your saved model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define the ImageDataGenerator for test data
test_datagen = ImageDataGenerator(rescale=1./255)  # You can add other preprocessing options here if needed

# Set up the test generator
test_generator = test_datagen.flow_from_directory(
    '/content/dataset/test',
    target_size=(224, 224),
    batch_size=1,
    class_mode='categorical',
    shuffle=False
)


# Obtain predicted classes for the test set
Y_pred = model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)

# Get true labels
true_labels = test_generator.classes

# Create confusion matrix
conf_matrix = confusion_matrix(true_labels, y_pred)

# Get class names
class_names = list(test_generator.class_indices.keys())

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='BuGn', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Found 361 images belonging to 5 classes.
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import load_model

# Load the saved model
model = load_model('/content/drive/MyDrive/savedmodels/epochsCNN.h5')  # Load your saved model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define the ImageDataGenerator for test data
test_datagen = ImageDataGenerator(rescale=1./255)  # You can add other preprocessing options here if needed

# Set up the test generator
test_generator = test_datagen.flow_from_directory(
    '/content/dataset/test',
    target_size=(224, 224),
    batch_size=1,
    class_mode='categorical',
    shuffle=False
)


# Obtain predicted classes for the test set
Y_pred = model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)

# Get true labels
true_labels = test_generator.classes

# Create confusion matrix
conf_matrix = confusion_matrix(true_labels, y_pred)

# Get class names
class_names = list(test_generator.class_indices.keys())

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Oranges', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Found 361 images belonging to 5 classes.
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import load_model

# Load the saved model
model = load_model('/content/drive/MyDrive/savedmodels/epochsCNN.h5')  # Load your saved model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define the ImageDataGenerator for test data
test_datagen = ImageDataGenerator(rescale=1./255)  # You can add other preprocessing options here if needed

# Set up the test generator
test_generator = test_datagen.flow_from_directory(
    '/content/dataset/test',
    target_size=(224, 224),
    batch_size=1,
    class_mode='categorical',
    shuffle=False
)


# Obtain predicted classes for the test set
Y_pred = model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)

# Get true labels
true_labels = test_generator.classes

# Create confusion matrix
conf_matrix = confusion_matrix(true_labels, y_pred)

# Get class names
class_names = list(test_generator.class_indices.keys())

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='YlOrBr', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Found 361 images belonging to 5 classes.
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 361/361 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
